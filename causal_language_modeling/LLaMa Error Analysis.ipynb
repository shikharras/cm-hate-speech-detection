# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report

# %% [markdown]
# ## Error Analysis

# %%
with open("data/predictions/llama-ft-completion_custom_data.pickle", "rb") as f:
    preds = pickle.load(f)
    
test_df = pd.read_csv("data/cm_hate_combined.csv")
test_df["pred"] = preds

# %%
mislabelled = test_df[test_df["offense"] != test_df["pred"]]

# %% [markdown]
# ### Gender

# %%
mislabelled[mislabelled["domain"] == "gender"][["offense", "pred"]].value_counts()
# Out:
# offense  label
# 1        0        46
# 0        1        23
# Name: count, dtype: int64

# %% [markdown]
# Sarcasm
# * Actual Label = 0, Predicted Label = 1;
#     Suna he Ek ladki roj Twitter pe Sher Aya Sher Aya bolti thi Aaj Khud hi Shikar ho gayi😪🔪IYKYK😏
# * Actual Label = 1, Predicted Label = 0
# @user Aarti utaro Kam dimag aurat ki ... 😆
#
# Not targeted towards women directly but implicit hate
# * Actual Label = 1, Predicted Label = 0
# @user @user Ladkiya to badi clout chasers milti hay bhay ko hamesha
#
# **Obvious misclassifications [Perhaps lack of similar train data]**
# * Actual Label = 1, Predicted Label = 0
# @user @user @user @user Aur khut aurat hai tu ye bhi Allah dekh raha. Koi gasht nhi karti auratein. Jab teri aukaat tujhe dikha di toh jhut bakne lagi
#
# * Actual Label = 1, Predicted Label = 0
# @user @user Bahut pyass Ess aurat ko
#  Kash ekk Barr mill jaye😂
#
# * Actual Label = 1, Predicted Label = 0
# @user 😏ja na gawar ladki
#
# Agressive but not offensive
# * Actual Label = 0, Predicted Label = 1
# @user apnay ghar ki khabar ni ho gi inhein 😡😠 phalestine pur boltay jaan jati hy in ki , itni gairat hy to jayain phalestine k lyay bol k dikhayain is tarah road pur kharay ho kar 😠😡 laikin ni , akeli aurat ko pareshan kr rahay hain 😡😠
#
# **Lack of understanding of cultural/ domain-specific terms**
# * Actual Label = 1, Predicted Label = 0
# @user @user calls him a 'Dehati Aurat'. It has been getting more apparent why with each passing day.
#
# **Different ways of spelling the same thing + Typos [Nuance of social media data]**
# * Actual Label = 1, Predicted Label = 0
# yeh ladki moean karte time bhi Mahi Mahi ki awaaj nikalti hai
#
# * Actual Label = 1, Predicted Label = 0
# @user Bkl pajeeta you made a video of so many people without their consent and uploaded on social media where million can see. Yahi sikhaya gya hai tujhe aurato or baccho ki video bana kar sab ko dikhana. Sudhar jaa bhen ki love di

# %%
for idx, row in mislabelled[mislabelled["domain"] == "gender"].iloc[:30].iterrows():
    print(f"Actual Label = {row['offense']}, Predicted Label = {row['pred']}")
    print(row['tweet'], "\n", "-"*75)
# Out:
# Actual Label = 0, Predicted Label = 1
# @user @user @user @user @user Matlab sirf ladki ke character baat ithae tab bologe 0ar ladke ke upar wo bhi khud ke fd se karoge to chup rahoge.
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Shit gharake SB aurat ko halala karate hai
#
#
#  Kaisi jamat hai
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Suna he Ek ladki roj Twitter pe Sher Aya Sher Aya bolti thi Aaj Khud hi Shikar ho gayi😪🔪IYKYK😏
#
#
#  PG Aur Khelo Expose Expose 😂
#  #Abhisha #AbhishaFam
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user @user Ladkiya to badi clout chasers milti hay bhay ko hamesha
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user Aik aurat jitni kosis krle bina mard ke maa nhi bn skti
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user @user @user @user Aur khut aurat hai tu ye bhi Allah dekh raha
#
#
#  Koi gasht nhi karti auratein
#
#
#  Jab teri aukaat tujhe dikha di toh jhut bakne lagi
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user apnay ghar ki khabar ni ho gi inhein 😡😠 phalestine pur boltay jaan jati hy in ki , itni gairat hy to jayain phalestine k lyay bol k dikhayain is tarah road pur kharay ho kar 😠😡 laikin ni , akeli aurat ko pareshan kr rahay hain 😡😠
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# entertainment ke liye chachi ke videos upload karo re🍿🤣🤣🤣 jab wo fanaya Sanaya jo bhi uske sath teja nach rhi thi tab chachi ko itna dar lga ki jaise wo ladki bta hi dene wali hai chachi uske sath bhi soya tha🤣abusive chachi bahar padi uske undra ki🤣🤣 #TejRan
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user @user Bahut pyass Ess aurat ko
#
#
#  Kash ekk Barr mill jaye😂
#
#
#  @user
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user Don't play aurat card here... is ek aurat ne apke mulk ke PM ko ungliyon per nachaya hua tha... sirf PM ko he naheen balkay poora system ko...
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user @user Aurat card kahy ko khel rahy youthiay ?? 😂😂
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user @user calls him a 'Dehati Aurat'. It has been getting more apparent why with each passing day.
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user @user Conductor ne usko ladki cherne se roka..mtlb ladki cherne se rokne pe badtamizo hogae aur chalo badtamizi ki v toh gardan utara jaega tab toh us hisab daily koto ki aahuti dedijani chahie
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Itna kya mixpod accha lagata hai aurat jaat ko....kuch aur phuko.
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user @user Bhaiya, irony yahan ye h ki same ladki thirst tweets krti h abhi pr n once she tweeted abt our girl jb uska tony kakkar ke sath voh funny reel aaya tha ki her gf/bf contents r really very cringe. Mtlb tm karo to rasleela, aur jbki hmari bandi aise explicit terms use v ni krti.
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user @user @user @user Being a girl being a girl trust me ab khud ladki hone ke bawajood is sabd se nafrat horhi ,har cheez me women card
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user Aarti utaro Kam dimag aurat ki ... 😆
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Ye ladka sare videos mein apne muh se ladki ke muh mein pour karta h
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Khujli mitana hai to waisa mard dhundo har kisi ke bas ki baat nhi hoti aurat ki pyas bujhana
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user 😏ja na gawar ladki
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# Iss ladki ko unfollow krr rha hu bhai pura din Mera Lunn ye, mera Lunn wo krti rhti hai tl pe iske paas hai bhi nhi phir bhi 😭😭
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user Mere ko Shak hai ki ladki bhi ya nahi 🤣🤣🤣
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user Paggal hai yeh aurat aishwarya..
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user @user @user @user Aaj aa jana apne doodh ka hisab kar lena mahine ka, jake baap daada se poch tumhari ladkiya thakuro ke yaha nachwate the aur paisa kamate the
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user Bkl pajeeta you made a video of so many people without their consent and uploaded on social media where million can see. Yahi sikhaya gya hai tujhe aurato or baccho ki video bana kar sab ko dikhana. Sudhar jaa bhen ki love di
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user @user Wo vaise hi kharab ladki h,i think she is ex-abhiya may be...I already blocked her so it means she also previously do bad post for #ManishaRani
#
#
#  #ManishaSquad do not keep attention on these cheap people.
#  Do streaming latest vlogs and #BaarishKeAaneSe
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# yeh ladki moean karte time bhi Mahi Mahi ki awaaj nikalti hai
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Aajkal sabhi tharki hai chahe wo 8-9 saal ke bacche ho ya 80-90 saal ke or ladke ho ya ladki ab ab Modi ji ko hi dekh lo kanha 74 years ke ho rahe hai or kis tarike se 45 saal ki maloni ji ko line mar rahe the ab koi tumhe tharki bole to yahi bolana " yatha Raja thatha praja"
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Toh ladki pta, shaadi kr, aur jo kaam hai woh kr, waise bhai ek mere liye bhi ladki dhundh dena😂
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user @user Yaar sexy joshi,
#
#
#  Kabhi koi aisa repost bhi kar diya kro jisme ladka muslim ho aur ladki hindu...99% case to aise hi hote hai sweetu....itni cute hokar bhi aise dil todne wali one side baate na kro...
#
#
#  Anyway miss u so much meri laddu @user 😘😘
#  ---------------------------------------------------------------------------

# %% [markdown]
# ## Religion

# %%
mislabelled[mislabelled["domain"] == "religion"][["offense", "pred"]].value_counts()
# Out:
# offense  label
# 1        0        29
# 0        1        27
# Name: count, dtype: int64

# %% [markdown]
# **Different ways of spelling the same thing + Typos [Nuance of social media data]**
# * Actual Label = 1, Predicted Label = 0
# Ab kaun mcd Hindu-Muslim kar rha
#
# * Actual Label = 1, Predicted Label = 0
# Bhai Europe mein Dekho Europe jitne bhi suver musalman hai inko Europe se Nikal Raha hai
#
# **No profane word, Lack of nuanced understanding**
# * Actual Label = 1, Predicted Label = 0
# Marathi nhi Hindu... Marathi ke wajah se nhi Hindu hone ke wajah se Target kiya... musalman hota to nhi hota
#
# * Actual Label = 1, Predicted Label = 0
# Abe english toh sikh le likhne se pehle ..
#
# **Use of negative connotation words but not offensive**
# * Actual Label = 0, Predicted Label = 1
# Jaisa tumko Muslim atanki nhi pasand...
#  Waise humko Hindu atanki nhi pasand...
#  Hum bhi bhot se Hinduo ki izzat kartey hai,
#  Mager jahilo ki nhi...

# %%
for idx, row in mislabelled[mislabelled["domain"] == "religion"].iloc[:30].iterrows():
    print(f"Actual Label = {row['offense']}, Predicted Label = {row['pred']}")
    print(row['tweet'], "\n", "-"*75)
# Out:
# Actual Label = 1, Predicted Label = 0
# aree tum log hutiye ho kya .. tumlogo ki poori kahani uss ladke pe kyu revolve ho rhi .. jake kashmir region me dekho 370 hatne ke baad kitne bihari bas chuke hn waha local muslims se shadi karke .. local colleges me bhi bihari bhare hue hn udhar ke
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# Ab kaun mcd Hindu-Muslim kar rha
#
#
#  Humare paas Amber Zaidi,Kalaam Sir jaise bhi rhe hai
#
#
#  Takleef un gutter chaap suaro se hai,jo 2 kaudi k naali k keede,khaate yaha ka aur gaate waha ka hai
#  Fir Jihaad
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Haan tabhi Monu manesar jaise logo ko paal rakkha hai tumne
#  Tabhi cow pe NSA laga dete ho.
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# Monu manesar ne galat kiya iss bhadve ko chod kar
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# Monu Manesar ko bhi sath le jaya karo, wo aur achhe se JSR ka nara lagana sikha dega
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# is tarah to tum jeet liye election? Kitne Monu Manesar ko pakadwaoge? Pehle in aatankiyon ko to pakdo Khattar ji.
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Farzi handles ko chhor kar batana ki kisi muslim ne hashmi ke paksh mein kuchh bola ho. Kahe itne ghatiya vichaar rakhte ho man mein? Bhai, hindu muslim koi bhi ho qanoon sabke liye barabar ka hi ho. Monu manesar ke liye bhi vahi aur hashmi ke liye bhi vahi
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# Marathi nhi Hindu... Marathi ke wajah se nhi Hindu hone ke wajah se Target kiya... musalman hota to nhi hota
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Firqa parst mullah, ki wajah se musalman kabhi aik nai hosktay,..
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Aaj k nawaz sharif k faislay nay nafrst aur barhadi punjab khas kar dara ki nagri waloon say andaza hi gua k sharif khan dan ba haisiyat e nam nehad musalman daid camrin say kirdar v main kitna past hay
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# Vo musalman bhi desh ka bhala chahte honge, tum kab chahoge?
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# Bhai Europe mein Dekho Europe jitne bhi suver musalman hai inko Europe se Nikal Raha hai
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Jab vote musalman ko barbad karne ke naam pe doge to kya hoga koi baat nhi itna to sahlenge do char gaali denge Muslim ko sab khus ha jayenge
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# Videshi rohingya videshi Bangladeshi Musalman Bharat ke andar bhi Bharat ke Charon taraf madrase masjid banakar apna dhandha chala rahe hain yah kam hai Kashmir ghati Jaise Srishti Sansthan per bhi rohingya bus gaye hain kaun hai basane wala hai Bharat gherna China ki niti hai
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# Deleting What's App because
#  Muhhamad is Masenger 👍
#  #NITSrinagar
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# Abe english toh sikh le likhne se pehle ..
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Are sikh lo duniya se hi, shayad koi Secularism ka asli matlab hi samjha de.
#
#
#  Apna wala to waise bhi farzi hai.
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Tum kisi ko ghar vapsi ka mauka hi nahi doge kya?
#  Chahte ho kya vo kisi suitcase ya fridge mein mile?
#
#
#  Love-J had ki victims isliye bhi nahi vapsi kr pati kyonki society se acceptance nahi milta.
#
#
#  Tumse aisi asha nahi thi bhai.
#
#
#  Jab kuch galat vo bolegi toh uska virodh hoga.
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# RSS koh toh Sardar Patel Khatam hi Kardiya tha..per Nehruji ko Democracy ka Kida kata hua tha, joh Ban hatane ke liye Patelji ko majboor kiya !
#
#
#  Tumhara golwarkar naak ragad kar mafinama likha aur Kasam khai ki kabhi politics nahi karenge aur deshvirodhi harkat nahi karenge! 🤬
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Ap bohot masoom ho yah Choron kaysath Milay howay ho?
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# Eska baap bhi koi hero nhi tha, Afghanistan me jihad ke naam pr Dehshatgard paida krne wale logon me se tha. 30 sal Afghanistan or Pakistan Dehshatgardi Ka shukar inhi logon ki wajah se rahe
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# इस Genocide के विरुद्ध #Islamic #Jihad और #Hamas ने जीत हासिल करके इस्लाम के नाम से पीड़ित लोगो को भी चुनौती दी है। अब अंधभक्त पोस्ट के निचे हगे बिना मानेगे नहीं
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Kripya meri aur mere Parivar ki raksha Karen hamen Suraksha pradan Karen ham per hamla karne Wale jihadi Abhi Tak nahin pakde gaye hain.
#   R.Yuva Hindu Vahini
#  9454435009
#  6394214399
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# क्लास में मुख से संभोग सिखाने वाला प्रोफेसर इख़्तियार अहमद निलंबित, केरल की यूनिवर्सिटी में क्लासरूम को बना दिया था सेक्स और यौन आनंद का अड्डा
#
#
#  #Kerala #SexualMolestation
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Wo sab to theek hai par bhai ne reverse love jihad kar diya 🫡
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Don’t forget Nazir Hussain, the dukhiyari of all Baaps! Main meri pagdi aap ke pairon par rakhta hoon. Baraat ko waapas mat le jaaiye…!
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# Jato ki pagdi Ashok gahlot ke aagey bicha di, kishan kom....🤣🤣
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Asa Kay 1000sqft cha Ghar tumhi MP Ani MLA la dete aamhi garib manhus Kay paap kela pagdi madhun Ghar gheun nalayak landlord redvlopmnt karat nai tumhala 3 mahine zale letter dilya tumhi pan Kay uttar nai dile 4 varshana ami 16 tenant Bina bhade bhar farte tumhala laaj vatat kay
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Fir 10 saal itna drama Kyun kar rahe the so called hindutvadi?
#  Waise Sahi kaha 100 crore Hindu ek Hindu PM/HM ke Raaj me bahot akele hain 😂😂😂
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Jaisa tumko Muslim atanki nhi pasand...
#  Waise humko Hindu atanki nhi pasand...
#  Hum bhi bhot se Hinduo ki izzat kartey hai,
#  Mager jahilo ki nhi...
#  ---------------------------------------------------------------------------

# %% [markdown]
# ## Sexual Orientation

# %%
mislabelled[mislabelled["domain"] == "orientation"][["offense", "pred"]].value_counts()
# Out:
# offense  label
# 0        1        28
# 1        0         9
# Name: count, dtype: int64

# %% [markdown]
# **Lack of understanding of cultural/ domain-specific terms**
# * Actual Label = 1, Predicted Label = 0
# @user @user @user @user Sir .
# yeh to Meetha hai🙆😐
# * Actual Label = 1, Predicted Label = 0
# @user @user Modi ke saath ye dusra hijda kon hai  koyi bata sakta hai
# * ❤️de kamzor mard
#
# **No profane word, Lack of nuanced understanding**
# * Actual Label = 1, Predicted Label = 0
# @user Islamophobia aur aghe ke teen shabd ek saath mat likh ,apne allah se to dar , queer ka saath dega to jannat nahi milegi
#
# Actual Label = 1, Predicted Label = 0
# @user @user @user Tu toh pehen hi liyo bhai best hoga Vasectomy karwa kiyo fir apne bacho ko traumatise karega

# %%
for idx, row in mislabelled[mislabelled["domain"] == "orientation"].iloc[:30].iterrows():
    print(f"Actual Label = {row['offense']}, Predicted Label = {row['pred']}")
    print(row['tweet'], "\n", "-"*75)
# Out:
# Actual Label = 1, Predicted Label = 0
# @user Agar Brian hota tho parents ka bath sunke queer nahee bante..
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Par PRIDE toh queers logon ka hota hai na.
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user @user @user Tu toh pehen hi liyo bhai best hoga Vasectomy karwa kiyo fir apne bacho ko traumatise karega
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user @user @user @user Sir .
# yeh to Meetha hai🙆😐
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user @user Tum jaise log pride ko pandal banake chodoge. Matlab queer logon ke siva baaki sab allowed, Mummy, papa, kutta, billi, bacche, Sharma ji ka beta, phalana dimkana
# pride ki history padlo. Pride queer logon ke liye hai. Tumhare cishet rishtedaro ke liye to 365 din pade hain saal me.
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user @user @user @user Ye agaya g@user ki paidaish
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Yeh Queer kya hote hain?
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user As chuttiye ko yeh bhe nahi pata queer or transgender main farak hotaa hai.
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user @user @user You haven't roasted my shit yet &amp; talking about my ass, thakta toh tu nahi hoga roz 16 saal ke baccho ko pareshan karte waqt apne kamzor mardangi ko chhupane ke liye, uski fikar rakh, dusro ke queer hone se teri mardaangi chali jaati hai ❤️de kamzor mard
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Logon me samajh nahi hai.. In queers ko Palestine me koi jagah nahi milegi, lekin fir bhi apni duniya me jee rahe
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user Islamophobia aur aghe ke teen shabd ek saath mat likh ,apne allah se to dar , queer ka saath dega to jannat nahi milegi
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Queer hota kya hai?
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Ye Queer kya hota hai 😭😭
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Ek train safar ke dauran, apni sexuality ko gupt rakhne waale mard se sexual mulaqat par, @user ye puchne ko majboor ho jaata hai ki aakhir mard mardangi ko lekar itni sakht soch kyon rakhte hain.
#
#
#
# #AOIPersonalStories #Masculinity #LGBTQIA
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Toh yeh batao inke reels dekh ke tumko ladki banne ka iccha hoti hai??? Agar nahi toh tum normal ho... Haa agar tumko views badane ke liye ladki banke drama karna hai thik hai,par tum kabhi LGBTQ march pe ni jaoge,ya toh dharam bhi change ni karoge...
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Brahamanvad, Hindutva etc sab sahi h par kya islam aur Christianity me LGBTQ+ ko support karne jaisa kuch hai kya jo yeh log unse aazadi nahi chahte hai?
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# -Occasion : Pride march
# -Slogans : Hindutva se azadi
#
# Funniest thing is there’s no law against LGBT in Hindutva but death penalty in IsIam but these clowns never speak against them.
#
# Do you need more proof that all such activism in India are sponsored by IsIamic ecosystem?
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user @user Modi ke saath ye dusra hijda kon hai  koyi bata sakta hai
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# Sare hijde aur gays mar Jaye toh pura duniya Shanti ka moksh ban jayega. Bohot acha hua us Instagram ka hijda pranshu ke saath
#  ---------------------------------------------------------------------------
# Actual Label = 1, Predicted Label = 0
# @user Ye gay/lesbian hai ki kya hai samajh nahi aata🤦. Ye 6kka kabhi free Palestine karta hai ya anti Brahminism karta hai. He/her/they/them/it ka koi content toh hota hi nhi.
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Yar bhai ap lesbian ho?
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Itne jyada gay lesbian log hai?
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Anushka insaan to tum bhi mujhe bilkul bhi sidhi nahi lagti, lesbian/bisexual ho kya🥹??
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user @user Bhai lesbian wedding karvadi tumne😂
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Lesbian porn sab ko dekhna hai lekin gay aadmi ko door se dekhte hi "hatt saale hijde" bolke bhaga dete hai waaah re samaj
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Paalne me ladki nahi chahiye lekin feed pe lesbian porn sab ko dekhna hai waah re samaj
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# Isse acha lesbian bnaa dete bhagwan 😔😔💔💔💔
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Desh ke liye toh lesbian bhi bann jaunga, gay kya cheez hai
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Arey ye lesbian hai.. ye khud revealed ki thi ek post me.. baad me wo post delete kar di
#  ---------------------------------------------------------------------------
# Actual Label = 0, Predicted Label = 1
# @user Usko pure bio me sirf lesbian samajh aaya
#  ---------------------------------------------------------------------------
