# %%
import re
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.metrics import cohen_kappa_score

# %%
from transformers import pipeline
model = pipeline("token-classification", model = "l3cube-pune/hing-bert-lid")

# %% [markdown]
# ## Read Data

# %%
df_women = pd.read_excel("Hate Speech Women Dataset.xlsx", sheet_name="annotations")
df_religion = pd.read_excel("Hate Speech Religion Dataset.xlsx", sheet_name="annotations")
df_lgbtq = pd.read_excel("Hate Speech LGBTQ Dataset.xlsx", sheet_name="annotations")

# %% [markdown]
# ## Annotator Agreement

# %%
def get_annotator_score(df):
    return cohen_kappa_score(df["label_1"], df["label_2"])

# %%
print(f"Women: {get_annotator_score(df_women)}")
print(f"Religion: {get_annotator_score(df_religion)}")
print(f"LGBTQ: {get_annotator_score(df_lgbtq)}")
# Out:
# Women: 0.7335647308708491
# Religion: 0.7575166687633664
# LGBTQ: 0.7199718210637548

# %%
round((get_annotator_score(df_women) + get_annotator_score(df_religion) + get_annotator_score(df_lgbtq))/3, 2)
# Out:
# 0.74

# %% [markdown]
# ## Preprocessing

# %%
def clean_tweet(tweet):
    # Remove usernames starting with @
    tweet_no_usernames = re.sub(r'@\w+', '@user', tweet)
    # Remove URLs
    tweet_no_urls = re.sub(r'http\S+|www\S+|\S+\.com\S+', '', tweet_no_usernames)
    return tweet_no_urls

# %% [markdown]
# ### Language Identification

# %%
def get_codemix_label(df):
    ''' Whether tweets are monolingual English or not (codemixed)'''
    # Note that here codemixed includes purely Devnagari script tweets as well
    codemixed = []

    for tweet in tqdm(df["tweet"].tolist()):
        result = model(tweet)
        
        hi_score = sum([token["score"] for token in result if token["entity"] == "HI"])
        hi_score_per_token = hi_score/len(result)
        codemixed.append(1) if hi_score_per_token>0.25 else codemixed.append(0)
        
    return codemixed

# %%
def get_preprocessed_data(df):
    df["majority_label"] = df["majority_label"].fillna(df["label_1"])
    df = df[["id", "tweet", "majority_label"]]
    df["tweet"] = df["tweet"].apply(clean_tweet)
    df = df.rename(columns={"id":"id", "tweet":"tweet", "majority_label":"offense"})
    df["offense"] = df["offense"].apply(int)
    df["codemixed"] = get_codemix_label(df)
    return df

# %%
df_women = get_preprocessed_data(df_women)
df_religion = get_preprocessed_data(df_religion)
df_lgbtq = get_preprocessed_data(df_lgbtq)
# Out:
# /var/folders/4q/0zjs2k9j7614z2wn36tgs8cm0000gn/T/ipykernel_69531/474337554.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["tweet"] = df["tweet"].apply(clean_tweet)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 278/278 [00:12<00:00, 22.00it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 257/257 [00:13<00:00, 18.81it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 106/106 [00:05<00:00, 21.08it/s]

# %%
df_women.head()
# Out:
#                     id                                              tweet  \
# 0  1729049443876601905  @user @user @user @user @user Matlab sirf ladk...
# 1  1729049269456589236  Pehle main bahut loyal tha tab mujhse koi ladk...
# 2  1729049238007615845  Shit gharake SB aurat ko halala karate hai\n \...
# 3  1729049218160144888  @user Yeh kya ho raha ha... kitna ghirna ha in...
# 4  1729048935900262571  Suna he Ek ladki roj Twitter pe Sher Aya Sher ...
#
#    offense  codemixed
# 0        0          1
# 1        0          1
# 2        0          1
# 3        0          1
# 4        0          1

# %% [markdown]
# ## Sanity Checks

# %%
df_women[df_women["codemixed"] == 0]["tweet"].tolist()[:5]
# Out:
# ["@user @user calls him a 'Dehati Aurat'. It has been getting more apparent why with each passing day.",
#  '@user #AbhishekKumar was absolutely right. She plays with others emotions. She has a boyfriend outside and she hid it like she hid it.\n #BiggBoss17 ',
#  "@user Exactly. It's a crime for women and normal for heroes. 🤷🏽\u200d♀️",
#  "During my College days, I used to save some money for my future by not hanging with any girl, didn't used to go to any Restaurants/ watching movies. But now wasting money for filling forms of all these Marriage bureaus for something which is never going to happen.",
#  '@user @user You are just blind hater of Dhoni, So talking to a Mf like you , is just waste of time 😪']

# %%
df_religion[df_religion["offense"]==1]["tweet"].tolist()[:5]
# Out:
# ['😂😂😂 abh smajh aa rha shivaji Maharaj ke Vansajon ne muslim dhram kyun swikara ...tum jeson ka inferiority complex dekh ke ...soja Bhai tere bhonkne se bhi kuch na hone vala kewal bigaad sakta hai baan nhi sakta',
#  'aree tum log hutiye ho kya .. tumlogo ki poori kahani uss ladke pe kyu revolve ho rhi .. jake kashmir region me dekho 370 hatne ke baad kitne bihari bas chuke hn waha local muslims se shadi karke .. local colleges me bhi bihari bhare hue hn udhar ke',
#  '😂😂 \n Aap bohot bahadur ho \n Itna to seh logi🤣🤣\n Mai to door hi rehta hu in matters se bhai kab kaun kaha peecha karta mil jaaye\n aur mere to muslim dost bhi hai kisi ne galti se dekh liya to pta nhi khud na kuch kre to kisi ko supari de dein meri😂😂',
#  'toh tum akbar ke waris ho.....naya naya suslim bane ho bht tez hain tumme....converted muslim banke apne ammi ch me to phd kar li hogi',
#  'Majlis tere jaise ko jawab Dena Sikha he hai. Ek number ka jahil Insaan.']

# %% [markdown]
# ## Export

# %%
df_women.to_csv("cm_hate_gender.csv", index=False)
df_religion.to_csv("cm_hate_religion.csv", index=False)
df_lgbtq.to_csv("cm_hate_orientation.csv", index=False)

# %%
df_women["domain"] = "gender"
df_religion["domain"] = "religion"
df_lgbtq["domain"] = "orientation"
df = pd.concat([df_women, df_religion, df_lgbtq], axis=0, ignore_index=True)
df
# Out:
#                       id                                              tweet  \
# 0    1729049443876601905  @user @user @user @user @user Matlab sirf ladk...
# 1    1729049269456589236  Pehle main bahut loyal tha tab mujhse koi ladk...
# 2    1729049238007615845  Shit gharake SB aurat ko halala karate hai\n \...
# 3    1729049218160144888  @user Yeh kya ho raha ha... kitna ghirna ha in...
# 4    1729048935900262571  Suna he Ek ladki roj Twitter pe Sher Aya Sher ...
# ..                   ...                                                ...
# 636  1731396941114753326            @user chal bay tu mere se zyada gay hai
# 637  1731396133090365622  @user Dollarsdikhao, yeh kesay bhee naachsin g...
# 638  1731395146665922983  @user Sorry to say that but ab logo ko khush d...
# 639  1731388742496096547                  @user bhai tu bohot gay hai wasey
# 640  1731387084471156886                                  NAMJOON IS GAY 🔥
#
#      offense  codemixed       domain
# 0          0          1       gender
# 1          0          1       gender
# 2          0          1       gender
# 3          0          1       gender
# 4          0          1       gender
# ..       ...        ...          ...
# 636        0          1  orientation
# 637        0          1  orientation
# 638        0          1  orientation
# 639        1          1  orientation
# 640        0          1  orientation
#
# [641 rows x 5 columns]

# %%
df.to_csv("cm_hate_combined.csv", index=False)

# %% [markdown]
# # Public Dataset

# %%
df_women_orig = pd.read_excel("Hate Speech Women Dataset.xlsx", sheet_name="annotations")
df_religion_orig = pd.read_excel("Hate Speech Religion Dataset.xlsx", sheet_name="annotations")
df_lgbtq_orig = pd.read_excel("Hate Speech LGBTQ Dataset.xlsx", sheet_name="annotations")

# %%
def create_public_df(df, df_orig):
    df_public = df_orig[["id", "label_1", "label_2"]].merge(df[["id", "offense"]])
    df_public["label_1"] = df_public["label_1"].apply(int)
    df_public["label_2"] = df_public["label_2"].apply(int)
    return df_public

# %%
df_women_public = create_public_df(df_women, df_women_orig)
df_women_public["domain"] = "gender"

df_religion_public = create_public_df(df_religion, df_religion_orig)
df_religion_public["domain"] = "religion"

df_lgbtq_public = create_public_df(df_lgbtq, df_lgbtq_orig)
df_lgbtq_public["domain"] = "orientation"

# %%
df_public = pd.concat([df_women_public, df_religion_public, df_lgbtq_public], axis=0, ignore_index=True)
df_public = df_public[["id", "domain", "label_1", "label_2", "offense"]]
df_public = df_public.rename(columns={"id":"tweet_id", "domain":"domain", 
                                      "label_1":"label_1", "label_2":"label_2", "offense":"majority_label"
                                     })
df_public
# Out:
#                 tweet_id       domain  label_1  label_2  majority_label
# 0    1729049443876601905       gender        0        0               0
# 1    1729049269456589236       gender        0        0               0
# 2    1729049238007615845       gender        0        0               0
# 3    1729049218160144888       gender        0        0               0
# 4    1729048935900262571       gender        0        0               0
# ..                   ...          ...      ...      ...             ...
# 636  1731396941114753326  orientation        1        0               0
# 637  1731396133090365622  orientation        1        0               0
# 638  1731395146665922983  orientation        0        0               0
# 639  1731388742496096547  orientation        1        0               1
# 640  1731387084471156886  orientation        0        0               0
#
# [641 rows x 5 columns]

# %%
df_public.to_csv("hinglish_hatespeech.csv", index=False)

# %%
label_cnts = df_public["majority_label"].value_counts()
label_cnts/label_cnts.sum()
# Out:
# 0    0.564743
# 1    0.435257
# Name: majority_label, dtype: float64

# %% [markdown]
# ## Language Identification Test (Hinglish)

# %%
tweets = df1["tweet"].tolist()

# %%
from transformers import pipeline

model = pipeline("token-classification", model = "l3cube-pune/hing-bert-lid")
result = model("yeh model chalta hai ki nai?")
result
# Out:
# [{'entity': 'HI',
#   'score': 0.9861215,
#   'index': 1,
#   'word': 'ye',
#   'start': 0,
#   'end': 2},
#  {'entity': 'HI',
#   'score': 0.76267576,
#   'index': 2,
#   'word': '##h',
#   'start': 2,
#   'end': 3},
#  {'entity': 'EN',
#   'score': 0.99998903,
#   'index': 3,
#   'word': 'model',
#   'start': 4,
#   'end': 9},
#  {'entity': 'HI',
#   'score': 0.99491715,
#   'index': 4,
#   'word': 'cha',
#   'start': 10,
#   'end': 13},
#  {'entity': 'HI',
#   'score': 0.7841624,
#   'index': 5,
#   'word': '##lta',
#   'start': 13,
#   'end': 16},
#  {'entity': 'HI',
#   'score': 0.98446053,
#   'index': 6,
#   'word': 'hai',
#   'start': 17,
#   'end': 20},
#  {'entity': 'HI',
#   'score': 0.97508156,
#   'index': 7,
#   'word': 'ki',
#   'start': 21,
#   'end': 23},
#  {'entity': 'HI',
#   'score': 0.8099531,
#   'index': 8,
#   'word': 'na',
#   'start': 24,
#   'end': 26},
#  {'entity': 'EN',
#   'score': 0.85855985,
#   'index': 9,
#   'word': '##i',
#   'start': 26,
#   'end': 27},
#  {'entity': 'EN',
#   'score': 0.9989041,
#   'index': 10,
#   'word': '?',
#   'start': 27,
#   'end': 28}]

# %%
model(tweets[43])
# Out:
# [{'entity': 'HI',
#   'score': 0.80155873,
#   'index': 1,
#   'word': 'ए',
#   'start': 0,
#   'end': 1},
#  {'entity': 'EN',
#   'score': 0.6006054,
#   'index': 2,
#   'word': '##क',
#   'start': 1,
#   'end': 2},
#  {'entity': 'HI',
#   'score': 0.99878865,
#   'index': 3,
#   'word': 'तरफ',
#   'start': 3,
#   'end': 6},
#  {'entity': 'HI',
#   'score': 0.6254365,
#   'index': 4,
#   'word': 'न',
#   'start': 7,
#   'end': 8},
#  {'entity': 'HI',
#   'score': 0.9868537,
#   'index': 5,
#   'word': '##ा',
#   'start': 8,
#   'end': 9},
#  {'entity': 'HI',
#   'score': 0.7897336,
#   'index': 6,
#   'word': '##र',
#   'start': 9,
#   'end': 10},
#  {'entity': 'HI',
#   'score': 0.9651025,
#   'index': 7,
#   'word': '##ी',
#   'start': 10,
#   'end': 11},
#  {'entity': 'EN',
#   'score': 0.62098646,
#   'index': 8,
#   'word': 'क',
#   'start': 12,
#   'end': 13},
#  {'entity': 'HI',
#   'score': 0.98527026,
#   'index': 9,
#   'word': 'स',
#   'start': 15,
#   'end': 16},
#  {'entity': 'HI',
#   'score': 0.93497354,
#   'index': 10,
#   'word': '##म',
#   'start': 16,
#   'end': 17},
#  {'entity': 'HI',
#   'score': 0.7693046,
#   'index': 11,
#   'word': '##म',
#   'start': 18,
#   'end': 19},
#  {'entity': 'HI',
#   'score': 0.9756562,
#   'index': 12,
#   'word': '##ा',
#   'start': 19,
#   'end': 20},
#  {'entity': 'EN',
#   'score': 0.75948554,
#   'index': 13,
#   'word': '##न',
#   'start': 20,
#   'end': 21},
#  {'entity': 'EN',
#   'score': 0.97424424,
#   'index': 14,
#   'word': 'क',
#   'start': 22,
#   'end': 23},
#  {'entity': 'HI',
#   'score': 0.96777457,
#   'index': 15,
#   'word': '##ी',
#   'start': 23,
#   'end': 24},
#  {'entity': 'EN',
#   'score': 0.72886914,
#   'index': 16,
#   'word': 'ब',
#   'start': 25,
#   'end': 26},
#  {'entity': 'HI',
#   'score': 0.962188,
#   'index': 17,
#   'word': '##ा',
#   'start': 26,
#   'end': 27},
#  {'entity': 'EN',
#   'score': 0.8292529,
#   'index': 18,
#   'word': '##त',
#   'start': 27,
#   'end': 28},
#  {'entity': 'HI',
#   'score': 0.97717047,
#   'index': 19,
#   'word': 'ह',
#   'start': 29,
#   'end': 30},
#  {'entity': 'HI',
#   'score': 0.7366595,
#   'index': 20,
#   'word': '##ो',
#   'start': 30,
#   'end': 31},
#  {'entity': 'HI',
#   'score': 0.7826367,
#   'index': 21,
#   'word': '##त',
#   'start': 31,
#   'end': 32},
#  {'entity': 'HI',
#   'score': 0.9768345,
#   'index': 22,
#   'word': '##ी',
#   'start': 32,
#   'end': 33},
#  {'entity': 'EN',
#   'score': 0.84776443,
#   'index': 23,
#   'word': 'ह',
#   'start': 34,
#   'end': 35},
#  {'entity': 'HI',
#   'score': 0.92773145,
#   'index': 24,
#   'word': 'व',
#   'start': 37,
#   'end': 38},
#  {'entity': 'EN',
#   'score': 0.56207234,
#   'index': 25,
#   'word': '##ह',
#   'start': 38,
#   'end': 39},
#  {'entity': 'HI',
#   'score': 0.96241295,
#   'index': 26,
#   'word': '##ी',
#   'start': 39,
#   'end': 40},
#  {'entity': 'HI',
#   'score': 0.9959997,
#   'index': 27,
#   'word': 'द',
#   'start': 41,
#   'end': 42},
#  {'entity': 'HI',
#   'score': 0.9520821,
#   'index': 28,
#   'word': '##स',
#   'start': 43,
#   'end': 44},
#  {'entity': 'EN',
#   'score': 0.54957867,
#   'index': 29,
#   'word': '##र',
#   'start': 44,
#   'end': 45},
#  {'entity': 'HI',
#   'score': 0.50072736,
#   'index': 30,
#   'word': '##ी',
#   'start': 45,
#   'end': 46},
#  {'entity': 'HI',
#   'score': 0.9949654,
#   'index': 31,
#   'word': 'तरफ',
#   'start': 47,
#   'end': 50},
#  {'entity': 'HI',
#   'score': 0.9344352,
#   'index': 32,
#   'word': 'ए',
#   'start': 51,
#   'end': 52},
#  {'entity': 'HI',
#   'score': 0.51393604,
#   'index': 33,
#   'word': '##क',
#   'start': 52,
#   'end': 53},
#  {'entity': 'EN',
#   'score': 0.8993499,
#   'index': 34,
#   'word': 'न',
#   'start': 54,
#   'end': 55},
#  {'entity': 'HI',
#   'score': 0.9922328,
#   'index': 35,
#   'word': '##ा',
#   'start': 55,
#   'end': 56},
#  {'entity': 'HI',
#   'score': 0.6023494,
#   'index': 36,
#   'word': '##र',
#   'start': 56,
#   'end': 57},
#  {'entity': 'HI',
#   'score': 0.5637277,
#   'index': 37,
#   'word': '##ी',
#   'start': 57,
#   'end': 58},
#  {'entity': 'HI',
#   'score': 0.9960716,
#   'index': 38,
#   'word': 'द',
#   'start': 59,
#   'end': 60},
#  {'entity': 'HI',
#   'score': 0.9685735,
#   'index': 39,
#   'word': '##स',
#   'start': 61,
#   'end': 62},
#  {'entity': 'HI',
#   'score': 0.7424737,
#   'index': 40,
#   'word': '##र',
#   'start': 62,
#   'end': 63},
#  {'entity': 'HI',
#   'score': 0.77747065,
#   'index': 41,
#   'word': '##ी',
#   'start': 63,
#   'end': 64},
#  {'entity': 'HI',
#   'score': 0.9407557,
#   'index': 42,
#   'word': 'न',
#   'start': 65,
#   'end': 66},
#  {'entity': 'HI',
#   'score': 0.9923084,
#   'index': 43,
#   'word': '##ा',
#   'start': 66,
#   'end': 67},
#  {'entity': 'HI',
#   'score': 0.76810485,
#   'index': 44,
#   'word': '##र',
#   'start': 67,
#   'end': 68},
#  {'entity': 'HI',
#   'score': 0.7922114,
#   'index': 45,
#   'word': '##ी',
#   'start': 68,
#   'end': 69},
#  {'entity': 'HI',
#   'score': 0.94065034,
#   'index': 46,
#   'word': 'क',
#   'start': 70,
#   'end': 71},
#  {'entity': 'EN',
#   'score': 0.95077276,
#   'index': 47,
#   'word': '##ो',
#   'start': 71,
#   'end': 72},
#  {'entity': 'HI',
#   'score': 0.989129,
#   'index': 48,
#   'word': 'कुछ',
#   'start': 73,
#   'end': 76},
#  {'entity': 'HI',
#   'score': 0.9991025,
#   'index': 49,
#   'word': 'इस',
#   'start': 77,
#   'end': 79},
#  {'entity': 'HI',
#   'score': 0.9907646,
#   'index': 50,
#   'word': 'क',
#   'start': 80,
#   'end': 81},
#  {'entity': 'HI',
#   'score': 0.9478846,
#   'index': 51,
#   'word': '##द',
#   'start': 81,
#   'end': 82},
#  {'entity': 'EN',
#   'score': 0.6611825,
#   'index': 52,
#   'word': '##र',
#   'start': 82,
#   'end': 83},
#  {'entity': 'HI',
#   'score': 0.9920065,
#   'index': 53,
#   'word': 'स',
#   'start': 84,
#   'end': 85},
#  {'entity': 'HI',
#   'score': 0.9266054,
#   'index': 54,
#   'word': '##म',
#   'start': 85,
#   'end': 86},
#  {'entity': 'HI',
#   'score': 0.87020695,
#   'index': 55,
#   'word': '##म',
#   'start': 87,
#   'end': 88},
#  {'entity': 'HI',
#   'score': 0.9613388,
#   'index': 56,
#   'word': '##ा',
#   'start': 88,
#   'end': 89},
#  {'entity': 'HI',
#   'score': 0.9383848,
#   'index': 57,
#   'word': '##न',
#   'start': 89,
#   'end': 90},
#  {'entity': 'EN',
#   'score': 0.8848799,
#   'index': 58,
#   'word': 'द',
#   'start': 91,
#   'end': 92},
#  {'entity': 'EN',
#   'score': 0.5214643,
#   'index': 59,
#   'word': 'र',
#   'start': 94,
#   'end': 95},
#  {'entity': 'EN',
#   'score': 0.7029647,
#   'index': 60,
#   'word': '##ह',
#   'start': 95,
#   'end': 96},
#  {'entity': 'HI',
#   'score': 0.9080876,
#   'index': 61,
#   'word': '##ी',
#   'start': 96,
#   'end': 97},
#  {'entity': 'EN',
#   'score': 0.6020618,
#   'index': 62,
#   'word': 'ह',
#   'start': 98,
#   'end': 99},
#  {'entity': 'EN',
#   'score': 0.7503337,
#   'index': 63,
#   'word': '।',
#   'start': 100,
#   'end': 101},
#  {'entity': 'HI',
#   'score': 0.8944904,
#   'index': 64,
#   'word': 'ज',
#   'start': 106,
#   'end': 107},
#  {'entity': 'EN',
#   'score': 0.9163083,
#   'index': 65,
#   'word': '##ब',
#   'start': 107,
#   'end': 108},
#  {'entity': 'HI',
#   'score': 0.9883986,
#   'index': 66,
#   'word': 'न',
#   'start': 109,
#   'end': 110},
#  {'entity': 'HI',
#   'score': 0.9946748,
#   'index': 67,
#   'word': '##ा',
#   'start': 110,
#   'end': 111},
#  {'entity': 'HI',
#   'score': 0.77538943,
#   'index': 68,
#   'word': '##र',
#   'start': 111,
#   'end': 112},
#  {'entity': 'HI',
#   'score': 0.95706075,
#   'index': 69,
#   'word': '##ी',
#   'start': 112,
#   'end': 113},
#  {'entity': 'HI',
#   'score': 0.8794877,
#   'index': 70,
#   'word': 'ह',
#   'start': 114,
#   'end': 115},
#  {'entity': 'HI',
#   'score': 0.8929598,
#   'index': 71,
#   'word': '##ी',
#   'start': 115,
#   'end': 116},
#  {'entity': 'HI',
#   'score': 0.9261211,
#   'index': 72,
#   'word': 'न',
#   'start': 117,
#   'end': 118},
#  {'entity': 'HI',
#   'score': 0.9914027,
#   'index': 73,
#   'word': '##ा',
#   'start': 118,
#   'end': 119},
#  {'entity': 'HI',
#   'score': 0.6629406,
#   'index': 74,
#   'word': '##र',
#   'start': 119,
#   'end': 120},
#  {'entity': 'HI',
#   'score': 0.8841528,
#   'index': 75,
#   'word': '##ी',
#   'start': 120,
#   'end': 121},
#  {'entity': 'HI',
#   'score': 0.9392559,
#   'index': 76,
#   'word': 'क',
#   'start': 122,
#   'end': 123},
#  {'entity': 'EN',
#   'score': 0.9087492,
#   'index': 77,
#   'word': '##ो',
#   'start': 123,
#   'end': 124},
#  {'entity': 'HI',
#   'score': 0.986421,
#   'index': 78,
#   'word': 'स',
#   'start': 125,
#   'end': 126},
#  {'entity': 'HI',
#   'score': 0.92074376,
#   'index': 79,
#   'word': '##म',
#   'start': 126,
#   'end': 127},
#  {'entity': 'HI',
#   'score': 0.82462543,
#   'index': 80,
#   'word': '##म',
#   'start': 128,
#   'end': 129},
#  {'entity': 'HI',
#   'score': 0.9785404,
#   'index': 81,
#   'word': '##ा',
#   'start': 129,
#   'end': 130},
#  {'entity': 'EN',
#   'score': 0.66009367,
#   'index': 82,
#   'word': '##न',
#   'start': 130,
#   'end': 131},
#  {'entity': 'EN',
#   'score': 0.97122264,
#   'index': 83,
#   'word': 'न',
#   'start': 132,
#   'end': 133},
#  {'entity': 'EN',
#   'score': 0.5429826,
#   'index': 84,
#   'word': '##ह',
#   'start': 133,
#   'end': 134},
#  {'entity': 'HI',
#   'score': 0.9282393,
#   'index': 85,
#   'word': '##ी',
#   'start': 134,
#   'end': 135},
#  {'entity': 'HI',
#   'score': 0.9239296,
#   'index': 86,
#   'word': 'द',
#   'start': 136,
#   'end': 137},
#  {'entity': 'EN',
#   'score': 0.574247,
#   'index': 87,
#   'word': '##ग',
#   'start': 138,
#   'end': 139},
#  {'entity': 'HI',
#   'score': 0.8156357,
#   'index': 88,
#   'word': '##ी',
#   'start': 139,
#   'end': 140},
#  {'entity': 'HI',
#   'score': 0.9242698,
#   'index': 89,
#   'word': 'त',
#   'start': 141,
#   'end': 142},
#  {'entity': 'EN',
#   'score': 0.9884974,
#   'index': 90,
#   'word': '##ो',
#   'start': 142,
#   'end': 143},
#  {'entity': 'HI',
#   'score': 0.8969941,
#   'index': 91,
#   'word': 'अ',
#   'start': 144,
#   'end': 145},
#  {'entity': 'HI',
#   'score': 0.9872635,
#   'index': 92,
#   'word': '##न',
#   'start': 145,
#   'end': 146},
#  {'entity': 'EN',
#   'score': 0.5825769,
#   'index': 93,
#   'word': '##य',
#   'start': 147,
#   'end': 148},
#  {'entity': 'HI',
#   'score': 0.99972194,
#   'index': 94,
#   'word': 'कौन',
#   'start': 149,
#   'end': 152},
#  {'entity': 'HI',
#   'score': 0.9483623,
#   'index': 95,
#   'word': 'द',
#   'start': 153,
#   'end': 154},
#  {'entity': 'HI',
#   'score': 0.9359366,
#   'index': 96,
#   'word': '##ग',
#   'start': 155,
#   'end': 156},
#  {'entity': 'HI',
#   'score': 0.8188509,
#   'index': 97,
#   'word': '##ा',
#   'start': 156,
#   'end': 157},
#  {'entity': 'EN',
#   'score': 0.6465645,
#   'index': 98,
#   'word': '?',
#   'start': 158,
#   'end': 159},
#  {'entity': 'EN',
#   'score': 0.98078877,
#   'index': 99,
#   'word': '@',
#   'start': 164,
#   'end': 165},
#  {'entity': 'HI',
#   'score': 0.8705248,
#   'index': 100,
#   'word': 'abbas',
#   'start': 165,
#   'end': 170},
#  {'entity': 'HI',
#   'score': 0.5294621,
#   'index': 101,
#   'word': '_',
#   'start': 170,
#   'end': 171},
#  {'entity': 'EN',
#   'score': 0.5161056,
#   'index': 102,
#   'word': 'ni',
#   'start': 171,
#   'end': 173},
#  {'entity': 'HI',
#   'score': 0.7922817,
#   'index': 103,
#   'word': '##gh',
#   'start': 173,
#   'end': 175},
#  {'entity': 'EN',
#   'score': 0.83417076,
#   'index': 104,
#   'word': '##at',
#   'start': 175,
#   'end': 177},
#  {'entity': 'EN',
#   'score': 0.8759771,
#   'index': 105,
#   'word': '@',
#   'start': 178,
#   'end': 179},
#  {'entity': 'HI',
#   'score': 0.9755626,
#   'index': 106,
#   'word': 'ad',
#   'start': 179,
#   'end': 181},
#  {'entity': 'HI',
#   'score': 0.8268095,
#   'index': 107,
#   'word': '##v',
#   'start': 181,
#   'end': 182},
#  {'entity': 'HI',
#   'score': 0.52738625,
#   'index': 108,
#   'word': '_',
#   'start': 182,
#   'end': 183},
#  {'entity': 'EN',
#   'score': 0.53961915,
#   'index': 109,
#   'word': 'sha',
#   'start': 183,
#   'end': 186},
#  {'entity': 'EN',
#   'score': 0.8387692,
#   'index': 110,
#   'word': '##sha',
#   'start': 186,
#   'end': 189},
#  {'entity': 'EN',
#   'score': 0.97708887,
#   'index': 111,
#   'word': '@',
#   'start': 190,
#   'end': 191},
#  {'entity': 'HI',
#   'score': 0.9974611,
#   'index': 112,
#   'word': 'ana',
#   'start': 191,
#   'end': 194},
#  {'entity': 'HI',
#   'score': 0.98351395,
#   'index': 113,
#   'word': '##mi',
#   'start': 194,
#   'end': 196},
#  {'entity': 'HI',
#   'score': 0.66299486,
#   'index': 114,
#   'word': '##kam',
#   'start': 196,
#   'end': 199},
#  {'entity': 'EN',
#   'score': 0.79357034,
#   'index': 115,
#   'word': '##ber',
#   'start': 199,
#   'end': 202},
#  {'entity': 'EN',
#   'score': 0.7358786,
#   'index': 116,
#   'word': '@',
#   'start': 203,
#   'end': 204},
#  {'entity': 'HI',
#   'score': 0.9232804,
#   'index': 117,
#   'word': 'bind',
#   'start': 204,
#   'end': 208},
#  {'entity': 'HI',
#   'score': 0.9174738,
#   'index': 118,
#   'word': '##ass',
#   'start': 208,
#   'end': 211},
#  {'entity': 'EN',
#   'score': 0.599334,
#   'index': 119,
#   'word': '_',
#   'start': 211,
#   'end': 212},
#  {'entity': 'HI',
#   'score': 0.99996173,
#   'index': 120,
#   'word': 'lad',
#   'start': 212,
#   'end': 215},
#  {'entity': 'HI',
#   'score': 0.9309494,
#   'index': 121,
#   'word': '##ki',
#   'start': 215,
#   'end': 217},
#  {'entity': 'EN',
#   'score': 0.9738259,
#   'index': 122,
#   'word': '@',
#   'start': 218,
#   'end': 219},
#  {'entity': 'HI',
#   'score': 0.9995523,
#   'index': 123,
#   'word': 'sang',
#   'start': 219,
#   'end': 223},
#  {'entity': 'HI',
#   'score': 0.99736303,
#   'index': 124,
#   'word': '##eet',
#   'start': 223,
#   'end': 226},
#  {'entity': 'HI',
#   'score': 0.9905832,
#   'index': 125,
#   'word': '##aga',
#   'start': 226,
#   'end': 229},
#  {'entity': 'HI',
#   'score': 0.9045833,
#   'index': 126,
#   'word': '##rg',
#   'start': 229,
#   'end': 231},
#  {'entity': 'HI',
#   'score': 0.6345413,
#   'index': 127,
#   'word': '_',
#   'start': 231,
#   'end': 232},
#  {'entity': 'HI',
#   'score': 0.9451694,
#   'index': 128,
#   'word': '@',
#   'start': 233,
#   'end': 234},
#  {'entity': 'HI',
#   'score': 0.9883944,
#   'index': 129,
#   'word': 'swat',
#   'start': 234,
#   'end': 238},
#  {'entity': 'HI',
#   'score': 0.9781608,
#   'index': 130,
#   'word': '##ija',
#   'start': 238,
#   'end': 241},
#  {'entity': 'HI',
#   'score': 0.9931109,
#   'index': 131,
#   'word': '##ih',
#   'start': 241,
#   'end': 243},
#  {'entity': 'HI',
#   'score': 0.6372199,
#   'index': 132,
#   'word': '##ind',
#   'start': 243,
#   'end': 246},
#  {'entity': 'EN',
#   'score': 0.7651837,
#   'index': 133,
#   'word': '@',
#   'start': 247,
#   'end': 248},
#  {'entity': 'HI',
#   'score': 0.9967219,
#   'index': 134,
#   'word': 'j',
#   'start': 248,
#   'end': 249},
#  {'entity': 'HI',
#   'score': 0.9596396,
#   'index': 135,
#   'word': '##sp',
#   'start': 249,
#   'end': 251},
#  {'entity': 'HI',
#   'score': 0.99066836,
#   'index': 136,
#   'word': '##ve',
#   'start': 251,
#   'end': 253},
#  {'entity': 'HI',
#   'score': 0.9875516,
#   'index': 137,
#   'word': '##era',
#   'start': 253,
#   'end': 256},
#  {'entity': 'HI',
#   'score': 0.9557333,
#   'index': 138,
#   'word': '##mah',
#   'start': 256,
#   'end': 259},
#  {'entity': 'HI',
#   'score': 0.7986209,
#   'index': 139,
#   'word': '##ila',
#   'start': 259,
#   'end': 262},
#  {'entity': 'EN',
#   'score': 0.89670134,
#   'index': 140,
#   'word': '@',
#   'start': 263,
#   'end': 264},
#  {'entity': 'HI',
#   'score': 0.9990897,
#   'index': 141,
#   'word': 'bjp',
#   'start': 264,
#   'end': 267},
#  {'entity': 'HI',
#   'score': 0.9946626,
#   'index': 142,
#   'word': '##mah',
#   'start': 267,
#   'end': 270},
#  {'entity': 'HI',
#   'score': 0.9943561,
#   'index': 143,
#   'word': '##ila',
#   'start': 270,
#   'end': 273},
#  {'entity': 'HI',
#   'score': 0.95904374,
#   'index': 144,
#   'word': '##mo',
#   'start': 273,
#   'end': 275},
#  {'entity': 'HI',
#   'score': 0.96828943,
#   'index': 145,
#   'word': '##rch',
#   'start': 275,
#   'end': 278},
#  {'entity': 'HI',
#   'score': 0.6169295,
#   'index': 146,
#   'word': '##a',
#   'start': 278,
#   'end': 279},
#  {'entity': 'HI',
#   'score': 0.94565684,
#   'index': 147,
#   'word': 'https',
#   'start': 280,
#   'end': 285},
#  {'entity': 'EN',
#   'score': 0.55789155,
#   'index': 148,
#   'word': ':',
#   'start': 285,
#   'end': 286},
#  {'entity': 'EN',
#   'score': 0.6874803,
#   'index': 149,
#   'word': '/',
#   'start': 286,
#   'end': 287},
#  {'entity': 'EN',
#   'score': 0.87574625,
#   'index': 150,
#   'word': '/',
#   'start': 287,
#   'end': 288},
#  {'entity': 'EN',
#   'score': 0.66760296,
#   'index': 151,
#   'word': 't',
#   'start': 288,
#   'end': 289},
#  {'entity': 'HI',
#   'score': 0.6883703,
#   'index': 152,
#   'word': '.',
#   'start': 289,
#   'end': 290},
#  {'entity': 'HI',
#   'score': 0.5329462,
#   'index': 153,
#   'word': 'co',
#   'start': 290,
#   'end': 292},
#  {'entity': 'HI',
#   'score': 0.9031263,
#   'index': 154,
#   'word': '/',
#   'start': 292,
#   'end': 293},
#  {'entity': 'HI',
#   'score': 0.9963217,
#   'index': 155,
#   'word': 'ik',
#   'start': 293,
#   'end': 295},
#  {'entity': 'HI',
#   'score': 0.9864429,
#   'index': 156,
#   'word': '##z',
#   'start': 295,
#   'end': 296},
#  {'entity': 'HI',
#   'score': 0.98795354,
#   'index': 157,
#   'word': '##q',
#   'start': 296,
#   'end': 297},
#  {'entity': 'HI',
#   'score': 0.9884863,
#   'index': 158,
#   'word': '##lp',
#   'start': 297,
#   'end': 299},
#  {'entity': 'HI',
#   'score': 0.97673166,
#   'index': 159,
#   'word': '##37',
#   'start': 299,
#   'end': 301},
#  {'entity': 'EN',
#   'score': 0.989282,
#   'index': 160,
#   'word': '##x',
#   'start': 301,
#   'end': 302},
#  {'entity': 'EN',
#   'score': 0.6398881,
#   'index': 161,
#   'word': '##f',
#   'start': 302,
#   'end': 303}]

# %%
hi_scores = []
en_scores = []
hi_counts = []
total_counts = []

for tweet in tqdm(tweets):
    tweet = clean_tweet(tweet)
    result = model(tweet)
    
    hi = [token["score"] for token in result if token["entity"] == "HI"]
    en = [token["score"] for token in result if token["entity"] == "EN"]
    
    hi_scores.append(sum(hi))
    en_scores.append(sum(en))
    hi_counts.append(len(hi))
    total_counts.append(len(result))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 278/278 [00:17<00:00, 15.50it/s]

# %%
df1["hi_score"] = hi_scores
df1["en_score"] = en_scores
df1["hi_count"] = hi_counts
df1["total_count"] = total_counts
df1["hi_score_per_token"] = df1["hi_score"]/df1["total_count"]

df1["codemixed"] = df1["hi_count"]/df1["total_count"] > 0.25 # Not Monolingual English

# df1["monolingual_english"] = df1["hi_count"]/df1["total_count"] < 0.125
# df1["monolingual_hindi"] = df1["hi_count"]/df1["total_count"] > 1-0.125 # Identifies Hinglish words as HI
# df1["codemixed"] = ~(df1["monolingual_english"] | df1["monolingual_hindi"])

# %%
df1[~df1["codemixed"]]#["tweet"].values
# Out:
#                       id                                              tweet  \
# 31   1729045129699443057  @IndianTintin_ @mediacrooks calls him a 'Dehat...
# 85   1729036502095761839  @Shiva_Veeramas Exactly. It's a crime for wome...
# 151  1729027072184787057  During my College days, I used to save some mo...
# 209  1729014409908085188  @Pagal_aurat @mufaddal_vohra You are just blin...
# 233  1729207267982278883  @preachaaaa Constructive criticism: try to not...
# 237  1729191664508670325  The All India Trinamool Congress under the gui...
# 266  1729046371582525732  Hello dear Randi 😊😊🤗🤗\n @Randirobics\n Good Mo...
# 269  1725819588166762557  @SVOjha the verna system describe one in 4 cat...
#
#      label      hindi    english   hi_score   en_score  hi_count  total_count  \
# 31     1.0   4.624641  17.991381   4.624641  17.991381         5           23
# 85     0.0   1.708471  12.989679   1.708471  12.989679         2           15
# 151    0.0   0.850821  54.514729   0.850821  54.514729         1           56
# 209    1.0   1.895501  22.921377   1.895501  22.921377         2           25
# 233    0.0   2.989354  46.571347   2.989354  46.571347         3           50
# 237    0.0   7.636111  30.964689   7.636111  30.964689         8           39
# 266    0.0  10.191863  45.753986  10.191863  45.753986        11           58
# 269    0.0  12.208590  50.565623  12.208590  50.565623        15           67
#
#      codemixed  monolingual_english  monolingual_hindi  hi_score_per_token
# 31       False                False              False            0.201071
# 85       False                False              False            0.113898
# 151      False                 True              False            0.015193
# 209      False                 True              False            0.075820
# 233      False                 True              False            0.059787
# 237      False                False              False            0.195798
# 266      False                False              False            0.175722
# 269      False                False              False            0.182218

# %%
df1.sort_values(by="hi_score_per_token")["tweet"][:20].tolist()
# Out:
# ["During my College days, I used to save some money for my future by not hanging with any girl, didn't used to go to any Restaurants/ watching movies. But now wasting money for filling forms of all these Marriage bureaus for something which is never going to happen.",
#  '@preachaaaa Constructive criticism: try to not use word "Aurat" in your discourse because it is etymologically derogatory , as it means female genitals in Arabic.\n You can use alternate words like Stree for women or Mahila.',
#  '@Pagal_aurat @mufaddal_vohra You are just blind hater of Dhoni, So talking to a Mf like you , is just waste of time 😪',
#  "@Shiva_Veeramas Exactly. It's a crime for women and normal for heroes. 🤷🏽\u200d♀️",
#  'Hello dear Randi 😊😊🤗🤗\n @Randirobics\n Good Morning ☕️🥐⚘️⚘️\n Hope you had a beautiful purple 💜 Weekend.\n Have you and yours a fabulous 💜 week ahead.\n Enjoy your Monday as much as possible.\n My best wishes. Take good care.\n Hi Rickles! 🤗🤗\n #MondayMorning #MondayThoughts',
#  '@SVOjha the verna system describe one in 4 categories i.e kshatriya, bramin, veshya and shudra, the verna system is still prevalent in our society, you can go through various matrimonial sites there are separate columns for various varnas, also people still marry in their own varna/',
#  'The All India Trinamool Congress under the guidance and inspiration of Hon’ble Chairperson Smt @MamataOfficial is pleased to announce the list of new District Mahila Presidents across the state of West Bengal. https://t.co/gRFmzOFYEX',
#  "@IndianTintin_ @mediacrooks calls him a 'Dehati Aurat'. It has been getting more apparent why with each passing day.",
#  'Time to ban the word “Aurat” in India. \n Use better words instead like Mahila. \n \n\n Thanks to @MisraNityanand \n @myogiadityanath @myogioffice @narendramodi_in @NaziaElahiKhan1 @BJP4UP @JPNadda @nsitharaman #indianwomen #desigirls\n https://t.co/EZGZ2UkEhA',
#  '@Akash7988Devil #AbhishekKumar was absolutely right. She plays with others emotions. She has a boyfriend outside and she hid it like she hid it.\n #BiggBoss17 https://t.co/QSduqNpbin',
#  'Bro com to you tube chinal',
#  '@MahuaMoitra Farget Adani, you are selleble lady any one can use you, highly qualified veshya you are',
#  '@RiaRevealed @TajinderBagga sir look at this pathetic aurat',
#  '@vishwajeet995 @Ashkandy1980 @AshwiniSahaya @anant_d dont use word aurat as it is an urdu shabd and the origin of aurat in urdu is concerned with the private parts of women ..instead use mahila or shrimati https://t.co/KuRmLOY5cJ',
#  '@aditisstuff Relationship ki wajah se suicide krna should never an option. You have your whole family relying on you, loving you. You have your friends. But ek ladka/ladki ki wajah se you give up your life, how dumb is that',
#  '#Hyderabad: #AIMIM Mumbai Mahila President Campaigning In Support Of AIMIM #Malakpet Candidate Ahmed Balala.\n \n\n @RizwanaKhanMIM @aimim_national @balala_ahmed https://t.co/65T75ea6Rv',
#  '@rose_k01 Nice choice of the car by ladki wale though.',
#  "Omg Vicky Jain's mother is so goddamn toxic. I feel so sorry for #AnkitaLokhande and her mother. Kya hi rude aurat hai. #BIGGBOSS17",
#  '@Iravati_Kashyap @_VanMiho_ Wo vaise hi kharab ladki h,i think she is ex-abhiya may be...I already blocked her so it means she also previously do bad post for #ManishaRani\n \n\n #ManishaSquad do not keep attention on these cheap people.\n Do streaming latest vlogs and #BaarishKeAaneSe https://t.co/0yv4hMuosW',
#  'International Gasti ort']

# %%
df1.sort_values(by="hi_score_per_token").iloc[:15]#["tweet"][:20].tolist()
# Out:
#                       id                                              tweet  \
# 151  1729027072184787057  During my College days, I used to save some mo...
# 233  1729207267982278883  @preachaaaa Constructive criticism: try to not...
# 209  1729014409908085188  @Pagal_aurat @mufaddal_vohra You are just blin...
# 85   1729036502095761839  @Shiva_Veeramas Exactly. It's a crime for wome...
# 266  1729046371582525732  Hello dear Randi 😊😊🤗🤗\n @Randirobics\n Good Mo...
# 269  1725819588166762557  @SVOjha the verna system describe one in 4 cat...
# 237  1729191664508670325  The All India Trinamool Congress under the gui...
# 31   1729045129699443057  @IndianTintin_ @mediacrooks calls him a 'Dehat...
# 238  1729189719903478238  Time to ban the word “Aurat” in India. \n Use ...
# 35   1728675716680892892  @Akash7988Devil #AbhishekKumar was absolutely ...
# 257  1728073541982056496                         Bro com to you tube chinal
# 272  1722987426149269586  @MahuaMoitra Farget Adani, you are selleble la...
# 148  1729028160325607651  @RiaRevealed @TajinderBagga sir look at this p...
# 230  1729218781069603083  @vishwajeet995 @Ashkandy1980 @AshwiniSahaya @a...
# 220  1729012449238724975  @aditisstuff Relationship ki wajah se suicide ...
#
#      label      hindi    english   hi_score   en_score  hi_count  total_count  \
# 151    0.0   0.850821  54.514729   0.850821  54.514729         1           56
# 233    0.0   2.989354  46.571347   2.989354  46.571347         3           50
# 209    1.0   1.895501  22.921377   1.895501  22.921377         2           25
# 85     0.0   1.708471  12.989679   1.708471  12.989679         2           15
# 266    0.0  10.191863  45.753986  10.191863  45.753986        11           58
# 269    0.0  12.208590  50.565623  12.208590  50.565623        15           67
# 237    0.0   7.636111  30.964689   7.636111  30.964689         8           39
# 31     1.0   4.624641  17.991381   4.624641  17.991381         5           23
# 238    0.0   7.247824  22.398405   7.247824  22.398405         8           31
# 35     1.0   8.842888  25.764855   8.842888  25.764855        10           36
# 257    0.0   1.764003   4.995266   1.764003   4.995266         2            7
# 272    1.0   6.175919  15.752730   6.175919  15.752730         8           24
# 148    1.0   1.999988   4.537035   1.999988   4.537035         2            7
# 230    0.0  11.742826  27.345241  11.742826  27.345241        12           40
# 220    0.0  14.993580  35.530584  14.993580  35.530584        15           51
#
#      codemixed  monolingual_english  monolingual_hindi  hi_score_per_token
# 151      False                 True              False            0.015193
# 233      False                 True              False            0.059787
# 209      False                 True              False            0.075820
# 85       False                False              False            0.113898
# 266      False                False              False            0.175722
# 269      False                False              False            0.182218
# 237      False                False              False            0.195798
# 31       False                False              False            0.201071
# 238       True                False              False            0.233801
# 35        True                False              False            0.245636
# 257       True                False              False            0.252000
# 272       True                False              False            0.257330
# 148       True                False              False            0.285713
# 230       True                False              False            0.293571
# 220       True                False              False            0.293992
